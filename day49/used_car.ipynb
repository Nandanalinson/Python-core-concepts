# %%
import pandas as pd

# %%
df = pd.read_csv('used_cars_data.csv')

# %%
df
# Out:
#       S.No.                                               Name    Location  \
# 0         0                             Maruti Wagon R LXI CNG      Mumbai
# 1         1                   Hyundai Creta 1.6 CRDi SX Option        Pune
# 2         2                                       Honda Jazz V     Chennai
# 3         3                                  Maruti Ertiga VDI     Chennai
# 4         4                    Audi A4 New 2.0 TDI Multitronic  Coimbatore
# ...     ...                                                ...         ...
# 7248   7248                  Volkswagen Vento Diesel Trendline   Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI      Mumbai
# 7250   7250                             Nissan Micra Diesel XV     Kolkata
# 7251   7251                             Volkswagen Polo GT TSI        Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi
#
# ...

# %%
df.isna().sum()
# Out:
# S.No.                   0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 46
# Power                  46
# Seats                  53
# New_Price            6247
# Price                1234
# dtype: int64

# %%
# here only 7253 rows and in new_price 6247 is empy soits better to drop it

# also drop sno (no need of it , serial number)

# %%
# drop ----> sno
# drop ----> new_price

# %%
df = df.drop(columns=['S.No.', 'New_Price'])
# or
# df.drop(columns='S.No.',axis = 1, inplace = True)
# df.drop(columns='New_Price',axis = 1, inplace = True)
# df

# %%
df
# Out:
#                                                    Name    Location  Year  \
# 0                                Maruti Wagon R LXI CNG      Mumbai  2010
# 1                      Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2                                          Honda Jazz V     Chennai  2011
# 3                                     Maruti Ertiga VDI     Chennai  2012
# 4                       Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...                                                 ...         ...   ...
# 7248                  Volkswagen Vento Diesel Trendline   Hyderabad  2011
# 7249                             Volkswagen Polo GT TSI      Mumbai  2015
# 7250                             Nissan Micra Diesel XV     Kolkata  2012
# 7251                             Volkswagen Polo GT TSI        Pune  2013
# 7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi  2014
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# ...

# %%
df.isna().sum()
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 46
# Power                  46
# Seats                  53
# Price                1234
# dtype: int64

# %%
# brand = [maruthi,hydayi,....]
# split
# df['brand'] = df['Name'].str.split().str[0]
# or

# %%
# apply
# lambda
# lambda argument : expression
df['Brand'] = df['Name'].apply(lambda x:x.split()[0])
# created a new column with an exisiting column ----> feature extraction

# %%
df
# Out:
#                                                    Name    Location  Year  \
# 0                                Maruti Wagon R LXI CNG      Mumbai  2010
# 1                      Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2                                          Honda Jazz V     Chennai  2011
# 3                                     Maruti Ertiga VDI     Chennai  2012
# 4                       Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...                                                 ...         ...   ...
# 7248                  Volkswagen Vento Diesel Trendline   Hyderabad  2011
# 7249                             Volkswagen Polo GT TSI      Mumbai  2015
# 7250                             Nissan Micra Diesel XV     Kolkata  2012
# 7251                             Volkswagen Polo GT TSI        Pune  2013
# 7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi  2014
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# ...

# %%
df.dtypes
# Out:
# Name                     str
# Location                 str
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type                str
# Transmission             str
# Owner_Type               str
# Mileage                  str
# Engine                   str
# Power                    str
# Seats                float64
# Price                float64
# Brand                    str
# dtype: object

# %%
# object -----> string , to calculate mean , mode or median we have to convert it into int(values)
# int,float

# here , mileage is object dtype , we have to convert it into int. 
# in order to do that , we have to remove the extra km/kg unit "26.6 km/kg"
# so we could get 26.6 as an integer

# %%
df['Mileage'] = df['Mileage'].str.replace(' km/kg', '')

# %%
df['Mileage'] = df['Mileage'].str.replace(' kmpl', '')

# %%
df.dtypes
# Out:
# Name                     str
# Location                 str
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type                str
# Transmission             str
# Owner_Type               str
# Mileage                  str
# Engine                   str
# Power                    str
# Seats                float64
# Price                float64
# Brand                    str
# dtype: object

# %%
# to convert object into int/float , here errors = coerce means 
# it force any string value to get converted to Nan instead of raising an error
df['Mileage'] = pd.to_numeric(df['Mileage'], errors='coerce')
# or
# df['Mileage'] = df['Mileage'].astype(float)

# %%
df.dtypes
# Out:
# Name                     str
# Location                 str
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type                str
# Transmission             str
# Owner_Type               str
# Mileage              float64
# Engine                   str
# Power                    str
# Seats                float64
# Price                float64
# Brand                    str
# dtype: object

# %%
df['Engine'] = df['Engine'].str.replace('CC','')

# %%
df
# Out:
#                                                    Name    Location  Year  \
# 0                                Maruti Wagon R LXI CNG      Mumbai  2010
# 1                      Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2                                          Honda Jazz V     Chennai  2011
# 3                                     Maruti Ertiga VDI     Chennai  2012
# 4                       Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...                                                 ...         ...   ...
# 7248                  Volkswagen Vento Diesel Trendline   Hyderabad  2011
# 7249                             Volkswagen Polo GT TSI      Mumbai  2015
# 7250                             Nissan Micra Diesel XV     Kolkata  2012
# 7251                             Volkswagen Polo GT TSI        Pune  2013
# 7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi  2014
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage Engine  \
# ...

# %%
df['Engine'] = pd.to_numeric(df['Engine'], errors = 'coerce')

# %%
df.dtypes
# Out:
# Name                     str
# Location                 str
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type                str
# Transmission             str
# Owner_Type               str
# Mileage              float64
# Engine               float64
# Power                    str
# Seats                float64
# Price                float64
# Brand                    str
# dtype: object

# %%
df['Power'] = df['Power'].str.replace('bhp','')

# %%
df['Power'].value_counts()
# Out:
# Power
# 74        280
# 98.6      166
# 73.9      152
# 140       142
# null      129
#          ...
# 252         1
# 328.5       1
# 98.63       1
# 360         1
# 241.6       1
# Name: count, Length: 386, dtype: int64

# %%
# to locate null
df.loc[df['Power']=='null ']
# Out:
#                                          Name    Location  Year  \
# 76                   Ford Fiesta 1.4 SXi TDCi      Jaipur  2008
# 79                     Hyundai Santro Xing XL   Hyderabad  2005
# 89                     Hyundai Santro Xing XO   Hyderabad  2007
# 120      Hyundai Santro Xing XL eRLX Euro III      Mumbai  2005
# 143       Hyundai Santro Xing XO eRLX Euro II       Kochi  2008
# ...                                       ...         ...   ...
# 6891                          Toyota Etios GD     Kolkata  2013
# 6896                     Toyota Etios Liva GD   Hyderabad  2013
# 6947                      Toyota Etios Liva G       Delhi  2012
# 7092  Hyundai Santro Xing XG AT eRLX Euro III  Coimbatore  2007
# 7145                      Toyota Etios Liva G     Kolkata  2012
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 76               111111    Diesel       Manual      First    17.80  1399.0
# ...

# %%
df.Power
# Out:
# 0        58.16
# 1       126.20
# 2        88.70
# 3        88.76
# 4       140.80
#          ...
# 7248    103.60
# 7249    103.60
# 7250     63.10
# 7251    103.60
# 7252    170.00
# Name: Power, Length: 7253, dtype: float64

# %%
# to change null ---> empty(Nan)
# we need numpy

# %%
import numpy as np

# %%
# df['Power'] = df['Power'].str.strip()  # remove extra spaces
# df['Power'] = df['Power'].replace('', np.nan)      # replace empty strings with NaN

# %%
# df['Power'] = df['Power'].replace('null ', np.nan)  # replace with NaN
# or
df.loc[df.Power=='null ','Power'] = np.nan

# %%
# df['Power'] = pd.to_numeric(df['Power'],errors = 'coerce')
df['Power'] = df['Power'].astype(float)
# ValueError: could not convert string to float: 'null '
# here it raises an error as power column contains 
# 129 "null" written values , which is string.
# so here we have to change null to empty
# null(str) ---> empty(nan)

# %%
df.dtypes
# Out:
# Name                     str
# Location                 str
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type                str
# Transmission             str
# Owner_Type               str
# Mileage              float64
# Engine               float64
# Power                float64
# Seats                float64
# Price                float64
# Brand                    str
# dtype: object

# %%
# At first when we checked the empty values were : Power	46
# and now we replaced 'null ' with nan value, so the empty columns increased
# And now Power 175
df.isna().sum()
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 46
# Power                 175
# Seats                  53
# Price                1234
# Brand                   0
# dtype: int64

# %%
# Mileage 2  -----> unique --> mean/median
# Engine	46 -----> unique --> mode
# Power	175  -----> unique --> mean/median
# Seats	53   -----> unique --> mode
# Price	1234 -----> unique --> mean/median

# %%
df['Mileage'].unique()  #based on output we can take mean/median bcoz floating point numbers
# Out:
# array([26.6 , 19.67, 18.2 , 20.77, 15.2 , 21.1 , 23.08, 11.36, 20.54,
#        22.3 , 21.56, 16.8 , 25.2 , 12.7 ,  0.  , 13.5 , 25.8 , 28.4 ,
#        20.45, 14.84, 22.69, 23.65, 13.53, 18.5 , 14.4 , 20.92, 17.5 ,
#        12.8 , 19.01, 14.53, 11.18, 12.4 , 16.09, 14.  , 24.3 , 18.15,
#        11.74, 22.07, 19.7 , 25.4 , 25.32, 14.62, 14.28, 14.9 , 11.25,
#        24.4 , 16.55, 17.11, 22.9 , 17.8 , 18.9 , 15.04, 25.17, 20.36,
#        13.29, 13.68, 20.  , 15.8 , 25.  , 16.4 , 24.52, 22.1 ,  8.5 ,
#        15.1 , 16.95, 19.64, 16.5 , 18.53, 17.57, 18.  , 23.2 , 16.73,
#        17.  , 13.  , 17.68, 22.7 , 16.2 , 15.26, 23.  , 19.83, 14.94,
#        17.71, 14.74, 16.  , 22.32, 12.99, 23.3 , 19.15, 10.8 , 15.  ,
#        22.  , 21.9 , 12.05, 11.7 , 21.21, 20.73, 24.07, 19.  , 20.58,
#        19.27, 11.5 , 18.6 , 21.14, 11.05, 21.76,  7.81, 21.66, 17.2 ,
#        20.63, 19.4 , 14.8 , 26.  , 20.4 , 21.5 , 15.3 , 17.9 , 16.6 ,
# ...

# %%
df['Mileage'] = df['Mileage'].fillna(df['Mileage'].mean())

# %%
df.isna().sum()
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 0
# Engine                 46
# Power                 175
# Seats                  53
# Price                1234
# Brand                   0
# dtype: int64

# %%
df['Engine'].unique()  #here also we can use mode (here it is not float)
# Out:
# array([ 998., 1582., 1199., 1248., 1968.,  814., 1461., 2755., 1598.,
#        1462., 1497., 2179., 2477., 1498., 2143., 1995., 1984., 1197.,
#        2494., 1798., 2696., 2698., 1061., 1198., 2987.,  796.,  624.,
#        1999., 1991., 2694., 1120., 2498.,  799., 2393., 1399., 1796.,
#        2148., 1396., 1950., 4806., 1998., 1086., 1193., 2982., 1493.,
#        2967., 2993., 1196., 1799., 2497., 2354., 1373., 2996., 1591.,
#        2894., 5461., 1595.,  936., 1997.,   nan, 1896., 1390., 1364.,
#        2199.,  993.,  999., 1405., 2956., 1794.,  995., 2496., 1599.,
#        2400., 1495., 2523.,  793., 4134., 1596., 1395., 2953., 1586.,
#        2362., 1496., 1368., 1298., 1956., 1299., 3498., 2835., 1150.,
#        3198., 1343., 1499., 1186., 1590., 2609., 2499., 2446., 1978.,
#        2360., 3436., 2198., 4367., 2706., 1422., 2979., 1969., 1489.,
#        2489., 1242., 1388., 1172., 2495., 1194., 3200., 1781., 1341.,
# ...

# %%
df['Engine'] = df['Engine'].fillna(df['Engine'].mode())[0]

# %%
df.isna().sum()
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 0
# Engine                  0
# Power                 175
# Seats                  53
# Price                1234
# Brand                   0
# dtype: int64
